# %%
# anomaly/ outlier detection algorithm
# very efficient with lowe memory use,very applicable to high dimensional data

#based on the assumption that because anomalies are few and different from other data
#they can be isolated using a few partitions

# ınvariant to the choice of a distance metric(since it doesnt even use one)
