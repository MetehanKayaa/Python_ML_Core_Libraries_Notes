# %%
import streamlit as st

st.title("This is a title")

st.header("This is a header")

st.subheader("This is a subheader")

st.markdown("**Markdown** _is_ supported! [Visit Streamlit](https://streamlit.io)")

st.text("This is a plain text")

st.write("st.write() can handle *mixed content*, like **bold**, _italic_, and numbers:",123)

st.write("### Code Block Example")

st.code("""
#Python Example
def greet(name):
    return f"Hello {name}'"
print(greet("Streamlit")) """, language='python')

st.markdown("#### Inline LateX: $a^2 + b^2 = c^2$")
st.latex(r"\int_0^\infty e^{-x^2} dx = \frac{\sqrt{\pi}} {2}")

st.success("This is a success message!")
st.warning("Be Careful this is a warning")
st.error("Something went wrong")
st.info("this is information")
st.markdown("> **Tip** Use feedback messages to guide the user")

# %%
# fox in the box 

import streamlit as st

if st.button("Click Me"):
    st.write('Button Clicked')
    
choice = st.radio("Chooes an option:", ["Billy Strings","Nine Inch Nailse", "Trivium"])
st.write("You Selected", choice)

agree= st.checkbox("I agree")
if agree:
    st.write("Thanks for agreeing")


genre= st.selectbox("Pick a genre:", ['Metal', "Rock", "Bluegrass"])
st.write("Your fovorite Genre is:", genre)


metal_subgenre= st.multiselect("Pick your favorite metal genres:", ["Thrash Metal", "Death Metal", "Metalcore"])
st.write("Your favorite Metal Genres are:",metal_subgenre)


#imput kısmı

age= st.slider("Select your age:", 0, 100, 25 )
st.write("Age:",age)

number= st.number_input("Enter a number", min_value=0, max_value=100, value=7)
st.write("Number:",number)


text= st.text_input("Enter a lyrics:", value="bizimle anlaşamaz onlar", max_chars=100)
st.write("Lyrics:",text)


bio= st.text_area("Neden sen:",value="sss",height=12, max_chars=100)
st.write("Your bio:",bio)

# %%
# tarih saat

date= st.date_input("Pick a date")
st.write("Selected date:",date)

time = st.time_input("Pick a time", step=1800, value="09:30")
st.write("Selected time",time)

# %%
# dosya yükleme
uploaded_file = st.file_uploader("Upload a text file", type=['pdf','csv','txt'])

if uploaded_file is not None:
    content= uploaded_file.read().decode("utf-8")
    st.text_area("File content", content, height=200)

# %%
# tablolar
import streamlit as st
import pandas as pd
data= {
    'Name': ['Alice','Bob','Charlie'],
    'Age': [25,30,35],
    'City': ['New York', 'Londan', 'Paris']
}
df= pd.DataFrame(data=data)

st.write('### Using st.write() for DataFrame')
st.write(df)

st.write('Static Table')
st.table(df)

st.write('Interactive DataFrame')
st.dataframe(df)

# %%
#jsonın temel amacı veriyi hiyerarşik ve etkileşimli bir formatta
# sunmaktır 
#Kullanım Amacı	API yanıtları, yapılandırılmış 
# karmaşık veriler ve hata ayıklama (debugging).
import streamlit as st
import pandas as pd

person = {
    
    'name':'Alice',
    'age': 25,
    'skills': ['Python', 'Streamlit', 'Data Science']
}
st.write("Displayed with json")
st.json(person)
st.write("Dictionary displayed with st.write()", person)

# %%
#dynamic tablolar bir şeylerin eklenebildiği
import streamlit as st
import pandas as pd


data= {
    'Name': ['Alice','Bob','Charlie'],
    'Age': [25,30,35],
    'City': ['New York', 'Londan', 'Paris']
}
df= pd.DataFrame(data=data)

editable_df=st.data_editor(df,num_rows='dynamic')
st.write("Updated Dataframe")
st.write(editable_df)

# %%
# container ve sidebar yandan açılıp seni başka sayfaya atan
# eklenti
import streamlit as st
import pandas as pd


with st.container():
    st.write("This is inside a container")
    
col1, col2= st.columns(2)

with col1:
    st.write("Column 1 content")
    
with col2:
    st.write("Column 2 content")    
    
with st.expander("More info"):
    st.write("Hidden content revealed when expanded")
    
option = st.sidebar.selectbox("Select page:",['Home','Settings','About'])
st.sidebar.write("Sidebar Content here")

st.write(f"Current page:{option}")

# %%
#diveder böyle sayfayı boydan boya bölen çizgi
import streamlit as st
import pandas as pd

st.write("Above the divider")
st.divider()

st.caption("This is a small caption text below")

# %%
import streamlit as st
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# 1. Image
img = Image.new('RGB', (200, 100), color='skyblue')
st.image(img, caption="Simple Image", use_container_width=True)

# 2. Line Chart
data = pd.DataFrame(np.random.rand(20, 3), columns=['a', 'b', 'c'])
st.line_chart(data=data)

st.divider() # Araya bir çizgi çekelim daha düzenli dursun

# 3. Audio (İnternetten örnek bir ses dosyası linki)
st.subheader("Ses Çalar")
sample_audio_url = "https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3"
st.audio(sample_audio_url, format="audio/mp3")

# 4. Video (İnternetten örnek bir video dosyası linki)
st.subheader("Video Oynatıcı")
sample_video_url = "https://www.learningcontainer.com/wp-content/uploads/2020/05/sample-mp4-file.mp4"
st.video(sample_video_url, format="video/mp4")

# %%
import streamlit as st
html_code="""
<div style='background-color:red; padding:10px;>
    <h3>Customer HTML BLOCK </h3m>
    <p style='color:red;'>This is green text within a div </p>
    
</div>

"""

st.markdown(html_code, unsafe_allow_html=True)

# %% [markdown]
# ## FİRST PROJECT MİNİ ÇOK PENCERELİ WEBSİTE

# %%
# 1 mini project

import streamlit as st
import pandas as pd
import numpy as np

st.title("Metehan")
st.subheader("Jr. Data Scientist")


st.sidebar.title("Navigation")
section= st.sidebar.radio("Go to", ['About', 'Skills',"Experience", 'Education', 'Contact'])

skills={
    'Python': 0.8,
    "Machine Learning":0.4,
    'Streamlit': 0.2,
    "SQL": 0.9,
    "Data Visiulization":0.6
}

if section=="About":
    st.markdown(f"""
    Experienced data scientist with strong skills in analytics, machine learning, and storytelling with data.
    Passionate about turning data into actionable insights.                    
""")


elif section=="Skills":
    st.header("Skills Overview")
    for skill,level in skills.items():
        st.write(f"{skill}")
        st.progress(level)
        
    df_skills=pd.DataFrame({
        'Skill': list(skills.keys()),
        'Proficiency': list(skills.values())
})
    st.bar_chart(df_skills.set_index("Skill"))
        
        

elif section == "Experience":
    st.header("Work & Projects")
    
    with st.expander("Fraud Detection Web App"):
        # Metni en sola yaslayarak yazmalısın
        st.write("""
- Developed a real-time prediction tool using Streamlit and Scikit-learn.
- Implemented model serialization with Joblib for efficient deployment.
        """)
        
    with st.expander("Hospital No-Show Prediction (Datathon)"):
        st.write("""
- Engineered features from synthetic health records to predict attendance.
- Optimized models based on PR-AUC metrics.
        """)
    
    
elif section=="Education":
    st.header("Academic Background")
    st.write("**Yıldız Technical University**")
    st.write("- Double Major: Mathematical Engineering & Statistics")
    st.write("- Relevant Coursework: Cryptology, OOP, Probability Theory")
    
elif section == "Contact":
    st.header("Get in Touch")
    
    with st.form("contact_form"):
        name = st.text_input("Name")
        email = st.text_input("Email")
        message = st.text_area("Message")
        submit = st.form_submit_button("Send")
        
        if submit:
            st.success(f"Thanks for reaching out, {name}! (This is a demo form)")

# %%
# 1. projenin farklı bir versiyonu
# ------ Personal Resume App (Advanced with placeholders) ------
import streamlit as st
import pandas as pd

# Sidebar for navigation
st.sidebar.title("Navigation")
section = st.sidebar.radio("Go to", ["About", "Skills", "Experience", "Education", "Contact"])

# Data for skills
skills = {
    "Python": 0.9,
    "Machine Learning": 0.85,
    "Data Visualization": 0.8,
    "SQL": 0.75,
    "Big Data": 0.6,
}

# Header with name and title
st.title("?anyname")
st.subheader("Data Scientist")

if section == "About":
    st.markdown(f"""
    Experienced data scientist with strong skills in analytics, machine learning, and storytelling with data.
    Passionate about turning data into actionable insights.
    """)

elif section == "Skills":
    st.header("Skills Overview")
    for skill, level in skills.items():
        st.write(f"{skill}")
        st.progress(level)
    df_skills = pd.DataFrame({
        "Skill": list(skills.keys()),
        "Proficiency": list(skills.values())
    })
    st.bar_chart(df_skills.set_index("Skill")) #I will write a section and more about plotting in streamlit in the intermediate section, now we can just add it I guess


elif section == "Experience":
    st.header("Work Experience")

    with st.expander(f"Data Scientist | ?anycompanyname | Jan 2021 - Present"):
        st.write(f"""
        - Developed predictive models that increased sales by 15%.
        - Automated data pipelines saving 10+ hours/week.
        - Collaborated with cross-functional teams to deploy ML models in production.
        """)

    with st.expander(f"Data Analyst | ?anycompanyname | Jun 2018 - Dec 2020"):
        st.write(f"""
        - Created dashboards that improved decision-making.
        - Analyzed customer data to improve retention by 12%.
        """)

elif section == "Education":
    st.header("Education")
    st.write(f"**M.S. in Data Science** â€” University of Data, 2020")
    st.write(f"**B.S. in Computer Science** â€” Tech University, 2017")

elif section == "Contact":
    st.header("Get in Touch")
    col1, col2 = st.columns(2)
    with col1:
        email = st.text_input("Email")
        phone = st.text_input("Phone")
    with col2:
        linkedin = st.text_input("LinkedIn URL")
        portfolio = st.text_input("Portfolio URL")

    message = st.text_area("Message")

    if st.button("Send"):
        st.success("Thanks for reaching out! I'll get back to you soon.")

# Save and refresh.
# ------ streamlit run

# %% [markdown]
# # session state hafıza kaydetmek için kullanılır her seferinde sıfırlanmaz

# %%
# ıncrement button ve name input alma

import streamlit as st

st.title("Session State Demo")

if "counter" not in st.session_state:
    st.session_state.counter=0
    
    
if st.button("Increnment"):
    st.session_state.counter+=1    
    
st.write("Counter value:",st.session_state.counter)


if 'name' not in st.session_state:
    st.session_state.name ="Guest"

name_input= st.text_input("Enter in your name", st.session_state.name)
if name_input != st.session_state.name:
    st.session_state.name= name_input
    
st.write("Hello",st.session_state.name)

# %%
# giriş çıkış butonları
import streamlit as st

st.title("Session State Demo")

if 'logged_in' not in st.session_state:
    st.session_state.logged_in =False


if not st.session_state.logged_in:
    if st.button("Login"):
        st.session_state.logged_in= True
        st.success("You are now logged in")


else:
    st.write("Welcome back!")
    if st.button("Logout"):
        st.session_state.logged_in= False

# %%
# dosya yükleme kaydetme preview verme
import streamlit as st
import pandas as pd
import json

st.title("File upload and preview")


uploaded_file =st.file_uploader("Upload a CSV, Excel, or JSON file", type=['csv','xlsx','json'])

if uploaded_file:
        if uploaded_file.name.endswith(".csv"):
            df=pd.read_csv(uploaded_file)
            st.write("CSV preview")
            st.dataframe(df.head())
            
        elif uploaded_file.name.endswith(".xlsx"):
            df=pd.read_excel(uploaded_file)
            st.write("Excel preview")
            st.dataframe(df.head())
            
        elif uploaded_file.name.endswith(".json"):
            data=json.load(uploaded_file)
            st.write("JSON preview")
            st.json(data.head())

if uploaded_file:
    file_size= uploaded_file.size/1024
    st.write(f"File name: {uploaded_file.name}, Size: {file_size:.2f} KB")
    if file_size>500:
        st.warning("File is large preview may be limeted")



# dekaratör sayesinde büyük dosyalar rame atılır ve tekrar okunması gerekitğinde bütün kodlar en baştan çalışmaz
# çok kısa sürede okunur
@st.cache_data
def load_large_csv(file):
    return pd.read_csv(file)

st.write("Upload a large csv for caching demo")
large_csv=st.file_uploader("Uploaded CSV for caching", type=['csv'], key='large')

if large_csv:
    df_large=load_large_csv(large_csv)
    st.write("Cached CSV loaded")
    st.dataframe(df_large.head())

# %%
# grafikler

import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns


st.title("Built in Charts")

data=pd.DataFrame(np.random.randn(20,3), columns=['A','B','C'])


st.subheader("Line Chart")
st.line_chart(data=data, )

st.subheader("Area Chart")
st.area_chart(data=data, )

st.subheader("Bar Chart")
st.bar_chart(data=data, )




#3d yi 2 boyuta indirgeme plotly ile güzel bir graph

data=pd.DataFrame(np.random.randn(20,3), columns=['A','B','C'])


st.subheader("Plotly Demo")

fig=px.scatter(data, x='A', y='B', color='C', title="Plotly Scatter")
st.plotly_chart(fig)


#seaborn 
st.subheader("Seaborn Example")

fig, ax= plt.subplots()

sns.histplot(data['A'],kde=True, ax=ax)
st.pyplot(fig)

# %%
# form sayfası
import streamlit as st


st.title("Forms Demo")

with st.form("Contact Form"):
    name=st.text_input("Name")
    email= st.text_input("Email")
    message= st.text_area("Message")
    submitted=st.form_submit_button("submit")
    
if submitted:
    st.success(f"Thanks {name}, we will contact you at {email}")

# %%
# adım adım bir şeyler seçme
# step by step workflow 
import streamlit as st


st.title("Forms Demo v2")

if 'step' not in st.session_state:
    st.session_state.step=1

if 'name' not in st.session_state:
    st.session_state.name=""

if 'choice' not in st.session_state:
    st.session_state.choice=""


def next_step():
    st.session_state.step+=1
    

def restart():
    st.session_state.step=1
    st.session_state.name=""
    st.session_state.choice=""

# keyler st.station_state.key key yerine keyin tuttuğu değişken geliyor köprü vazifesi aslında
if st.session_state.step==1:
    st.write("Step 1: Enter your name")
    st.text_input("Name", value=st.session_state.name, key='name')
    st.button('Next', on_click=next_step)


elif st.session_state.step==2:
    st.write(f"Hello {st.session_state.name} Step 2:  Choose your preference")
    st.radio("Choose a resturant",value=['Chipottle','Moes'], key='choice')
    st.button('Next', on_click=next_step)


elif st.session_state.step==3:
    st.write(f"you selected {st.session_state.choice}")
    st.button('Restart', on_click=restart)

# %%
# bitcoin tracker anlık grafikli 
import streamlit as st
import requests
import pandas as pd

st.title("Bitcoin Price Tracker (via CoinGecko)")

# --------- Current Price ---------
price_url = "https://api.coingecko.com/api/v3/simple/price?ids=bitcoin&vs_currencies=usd"

try:
    price_response = requests.get(price_url, timeout=10)
    price_response.raise_for_status()
    price = price_response.json()["bitcoin"]["usd"]
    st.metric(label="Bitcoin Price (USD)", value=f"${price:,}")
except requests.exceptions.RequestException as e:
    st.error(f"Failed to fetch current price: {e}")

# --------- Historical Data ---------
history_url = "https://api.coingecko.com/api/v3/coins/bitcoin/market_chart"
params = {"vs_currency": "usd", "days": "60", "interval": "daily"}

try:
    history_response = requests.get(history_url, params=params, timeout=10)
    history_response.raise_for_status()
    prices = history_response.json()["prices"]

    df = pd.DataFrame(prices, columns=["Timestamp", "Price"])
    df["Date"] = pd.to_datetime(df["Timestamp"], unit='ms')
    st.line_chart(df.set_index("Date")["Price"])

except requests.exceptions.RequestException as e:
    st.error(f"Failed to fetch historical data: {e}")

# %%
# farklı sayfalar açma klasik
import streamlit as st
import requests
import pandas as pd


pages= ['Home','Dashboard', 'Settings']
choice= st.sidebar.radio("Go to", pages)

if choice == 'Home':
    st.header("Home Page")
    st.write("Welcome")

elif choice == 'Dashboard':
    st.header("Dashboard page")
    st.write("metrics and charts here")


elif choice == 'Settings':
    st.header("Dashboard Page")
    st.write("user preference here")

# %%
# lil dashboard
import streamlit as st


def show_header(title):
    st.markdown(f"## {title}")
    
    
def show_metric(label, value):
    st.metric(label=label, value=value)
    
    
show_header("Dashboard")
show_metric("Revenue","$10.000")
show_metric("Users","1,000")

# %%
# chromda gözüken yeri düzenleme
# pencere kısmı
import streamlit as st


st.set_page_config(
    page_title='My Custom App', # site adı
    page_icon="ðŸ“Š", #ta. ikonuı
    layout="wide",
    initial_sidebar_state="expanded"
)

# %%
# REAL TİME STOCK DASHBOARD
import streamlit as st
import yfinance as yf
import pandas as pd
from datetime import datetime



st.set_page_config(page_title="Stock Dashboard", layout="wide")

st.title("Realtime Stock Dashboard")


st.sidebar.header("Stock Settings")
ticker_symbol=st.sidebar.text_input("Enter Stock Symbol","AAPL")
period= st.sidebar.selectbox("Select Period",["1d","5d","1mo","6mo","1y","5y"])
interval= st.sidebar.selectbox("Select Interval",["1m","5m","15m","1h","1d"])
if period == "1mo" and interval == "1m":
    st.warning("⚠️ Yahoo Finance 1 aylık periyotta 1 dakikalık veri vermez. Aralık 5m olarak güncellendi.")
    interval = "5m"

ticker = yf.Ticker(ticker_symbol)
data = ticker.history(period=period, interval=interval)

if data.empty:
    st.error("Veri çekilemedi. Lütfen periyot ve aralık kombinasyonunu değiştirin.")

ticker=yf.Ticker(ticker_symbol)
data= ticker.history(period=period, interval= interval)

latest_price= data['Close'].iloc[-1] if not data.empty else "N/A"
st.metric(label=f"Current Price: {ticker_symbol}", value=f"${latest_price:.2f}" if latest_price!='N/A' else "No Data")


st.subheader(f"Price Chart for {ticker_symbol}")
if not data.empty:
    st.line_chart(data['Close'])

else:
    st.warning("No Data Avaiable for this symbol")

col1, col2, col3 =st.columns(3)


with col1:
    st.write("**Previous Close**",ticker.info.get("previousClose","N/A"))
   

with col2:
    st.write("**Market Cap**",ticker.info.get("marketCap","N/A"))


with col3:
    st.write("**52-Week High**",ticker.info.get("fiftyTwoWeekHigh","N/A"))

st.caption("Refresh page for updated data or adjust interval")

# %%
# 2. PROJE 
# GİRİLEN KONUMDAN SEÇİLEN KONUMLARA UZAKLIKLARINI BULMA

import pandas as pd
import streamlit as st
import googlemaps
import requests


API_KEY =  "AIzaSyCvObxpmqd1JZVVSbD3AsLS_WJJznmhGJg"



denver_locations = [
    {'location': 'Pikes Peak', 'Address': '515 Ruxton Ave, Manitou Springs, CO 80829'},
    {'location': 'Magnolia Road', 'Address': '45 Peak to Peak Hwy, Nederland, CO 80466'},

    {'location': 'Coors Field', 'Address': '2001 Blake Street, Denver, CO 80205'},
    {'location': 'Denver Card Show', 'Address': '5004 National Western Dr, Denver, CO 80216'},


    {'location': 'Fillmore Auditorium', 'Address': '2001 Blake Street, Denver, CO 80205'},
    {'location': 'Mission Ballroom', 'Address': '4242 Wynkoop St, Denver, CO 80216'},
    {'location': 'Red Rock Ampitheater', 'Address': '18300 W Alameda Pkwy, Morrison, CO 80465'},


]

st.title("House Distance Finder (Routes API)")
st.write("Enter your starting address:")

with st.form("address_form"):
    street = st.text_input("Street Address")
    city = st.text_input("City")
    state = st.text_input("State")
    zip_code = st.text_input("ZIP Code")
    submitted = st.form_submit_button("Submit")

if submitted:
    user_address = f"{street}, {city}, {state} {zip_code}"
    st.success(f"Calculating distances from: {user_address}")

    def get_distance_miles(origin, destination):
        url = f"https://routes.googleapis.com/directions/v2:computeRoutes?key={API_KEY}"

        headers = {
            "Content-Type": "application/json",
            "X-Goog-FieldMask": "routes.distanceMeters"
        }

        body = {
            "origin": {"address": origin},
            "destination": {"address": destination},
            "travelMode": "DRIVE"
        }

        try:
            response = requests.post(url, headers=headers, json=body)
            response.raise_for_status()
            data = response.json()

            meters = data["routes"][0]["distanceMeters"]
            miles = round(meters / 1609.34, 2)
            return miles
        except Exception as e:
            st.warning(f"Error for {destination}: {e}")
            return None

    # Collect results
    results = []
    for loc in denver_locations:
        miles = get_distance_miles(user_address, loc["Address"])
        results.append({
            "location": loc["location"],
            "Address": loc["Address"],
            "Distance (mi)": miles
        })

    # Create and display DataFrame
    df = pd.DataFrame(results).set_index("location")
    df2 = df.sort_values('Distance (mi)')
    st.dataframe(df2)

# %%
# 3d anomiasyon ekleme 

import streamlit as st
from streamlit_lottie import st_lottie
import requests

st.title("3rd party components")

def load_lottieurl(url):
    r = requests.get(url)
    if r.status_code ==200:
        return r.json()
    return None

lottie_url = "https://assets10.lottiefiles.com/packages/lf20_1pxqjqps.json"
lottie_json = load_lottieurl(lottie_url)
st_lottie(lottie_json, height=200)

# %%
# multi tabs yan yana seçenekler durur tıklayınca geçersin diğer sayfaya
import streamlit as st

st.title("Multi Tab Example")

tabs= st.tabs(['Summary','Details', 'Settings'])


with tabs[0]:
    st.header("Summary")
    st.write("Overview Content Here")


with tabs[1]:
    st.header("Details")
    st.write("Detail info  goes here")



with tabs[2]:
    st.header("Settings")
    st.write("User preferences Here")

# %%
# seçilen kategriyre göre uygun tablo kısımlarını getirme
import streamlit as st
import pandas as pd
import numpy as np

data= pd.DataFrame(
    {
        "Category": ["A","A","B","B","C","C"],
        "Subcategory": ["A1","A2","B1","B2","C1","C2"],
        'Value': np.random.randint(10,100,6)
       
    }
)

category= st.selectbox("Select Category", data['Category'].unique())


filtered = data[data['Category']==category]

st.write(f"Values for Category {category}")
st.table(filtered)

# %%
import streamlit as st
#  custom button tasarlama

st.title("Custom Theme Example")

st.markdown(
    """
   <style>
    .ccc-laumxhk{
        background-color: #f0f8ff;
    }
    
    .stButton>button {
        
        background-color:#4CAF50;
        color: white;}
    
    </style>
    """,
unsafe_allow_html=True

    
)
st.button("Styled Button")

# %%
öncesinde .streamlit klasöründe 
secrets.toml diye bri dosya açıp
[auth]
password="password" bunu yazdık

import streamlit as st

password_input= st.text_input("Enter password:",type="password")

if password_input==st.secrets['auth']['password']:
    st.success("Access Granted")
    st.write("Protected content in here")
else:
    st.warning("Enter the correct password!")

# %%
# kullancı admina arayüzü

import streamlit as st



if "user role" not in st.session_state:
    st.session_state.user_role = None
    

def login(user):
    roles= {'admin':'admin', 'user':'viewer'}
    st.session_state.user_role= roles.get(user,"viewer")
    
    
    
user= st.text_input("Username")
if st.button("Login"):
     login(user)
    
if st.session_state.user_role=='admin':
    st.success("Welcome Admin you have full access")
    st.write("Admin Content")
elif st.session_state.user_role =="viewer":
    st.info("Welcome viewer you have limited access")
    st.write("Viewer Content")


else:
    st.warning("Please Login")

# %%
# csv excel pdf okuyucu ve yükleyici
import streamlit as st
import pandas as pd
from io import BytesIO

st.title("Export Data Demo")

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Miles': [50, 60, 70],
    'Races': [5, 10, 15]
})

st.dataframe(df)

# --- CSV download ---
csv = df.to_csv(index=False).encode("utf-8")
# Hata: 'text/cs' yazmışsın, 'text/csv' olmalı
st.download_button(
    label="Download CSV",
    data=csv,
    file_name="data.csv",
    mime='text/csv'
)

# --- Excel download ---
def to_excel(df):
    output = BytesIO()
    # xlsxwriter kütüphanesinin yüklü olduğundan emin ol (pip install xlsxwriter)
    with pd.ExcelWriter(output, engine="xlsxwriter") as writer:
        df.to_excel(writer, index=False, sheet_name="Sheet1")
    processed_data = output.getvalue()
    return processed_data

excel_data = to_excel(df)

# Hata: Burada fazladan "data_xlsx" parametresi vardı, sildik.
st.download_button(
    label="Download Excel",
    data=excel_data,
    file_name="data.xlsx",
    mime="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet"
)


# for pdf

# PDF download (simple text PDF example)
from fpdf import FPDF

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)
for i, row in df.iterrows():
    pdf.cell(200, 10, txt=f"{row['Name']}, Miles: {row['Miles']}, Races: {row['Races']}", ln=True)

pdf_bytes = pdf.output(dest='S').encode('latin1')  # Correct way to get PDF as bytes
st.download_button("Download PDF", pdf_bytes, "report.pdf", "application/pdf")



#####################################################

st.title("File Upload History")

if 'uploads' not in st.session_state:
    st.session_state.uploads= []

uploaded_file =st.file_uploader("Upload a File")


if uploaded_file:
    st.session_state.uploads.append({
        'filename': uploaded_file.name,
        'size': uploaded_file.size,
        'type': uploaded_file.type
        
    })
    st.success(f"Uploaded {uploaded_file.name}")

st.write("Upload History")
st.table(st.session_state.uploads)

# %%
# yükleniyor çubuğu 5 snyde dolan bir bar

import streamlit as st
import time

st.title("Long running tasks")

with st.spinner("Processing Please Wait"):
    progress_bar = st.progress(0)
    for i in range(100):
        time.sleep(0.05)
        progress_bar.progress(i+1)
        
st.success("Task Completed")

# %%
# 5 kere output veren dinamik bir ekran
import streamlit as st
import time
import asyncio



st.title("Async Example")

async def async_task():
    for i in range(5):
        st.write(f"Async step {i+1}")
        await asyncio.sleep(1)
        
asyncio.run(async_task())
st.success("Async task done")

# %%
# bir şey yüklerken yada yaparken dönen simge
import streamlit as st
import time
import asyncio



st.title("Oueur based background tasks")

@st.cache_resource

def expensive_task(x):
    time.sleep(5)
    return f"Result for input {x}"


input_val = st.text_input("Enter something")

if st.button("run task"):
    with st.spinner("Runnig task in queue"):
        result=expensive_task(input_val)
    st.success(result)
